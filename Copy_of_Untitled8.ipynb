# %% [markdown]
# <a href="https://colab.research.google.com/github/solomonakpan126-stack/web-3-data-script/blob/main/Copy_of_Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
team1 = "Liverpool"
team2 = "Chelsea"
score1 = 4
score2 = 3

print(team1, "versus", team2)
print("Final score:", score1, "to", score2)
# Out:
# Liverpool versus Chelsea
# Final score: 4 to 3

# %%
# Asking for user input
first_name = input("What is your first name? ")
last_name = input("What is your last name? ")

# Calculating lengths
first_len = len(first_name)
last_len = len(last_name)

# Displaying the results
print(f"Your first name is {first_len} letters long")
print(f"Your last name is {last_len} letters long")
# Out:
# What is your first name? Solomon
# What is your last name? Akpan
# Your first name is 8 letters long
# Your last name is 6 letters long

# %%
# Assigning values to variables
name = "Freda"
feel = "happy"

# Printing the outputs using the variables
print(f"Hi {name}!")
print(f"I'm glad you feel {feel}.")
# Out:
# Hi Freda!
# I'm glad you feel happy.

# %%
# I. Define an integer variable
int_a = 10

# II. Define a floating-point variable
float_a = 10.0

# III. Define a string variable
string_a = "10"

# IV. Print values and their types
print(int_a, type(int_a))
print(float_a, type(float_a))
print(string_a, type(string_a))
# Out:
# 10 <class 'int'>
# 10.0 <class 'float'>
# 10 <class 'str'>

# %%
# 1. Assign the integer value 10 to meters
meters = 10

# 2. Assign the floating-point value 3.28 to meter2feet
meter2feet = 3.28

# 3. Calculate feet by multiplying meters by the conversion factor
feet = meters * meter2feet

# 4. Print the result
print(feet)
# Out:
# 32.8
